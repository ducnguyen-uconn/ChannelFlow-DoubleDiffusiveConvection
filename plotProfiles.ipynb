# %%
import vtk
def write_rectilinear_vtk(X, Y, data_dict, filename):
    # Create the rectilinear grid
    grid = vtk.vtkRectilinearGrid()
    grid.SetDimensions(len(X), len(Y), 1)

    # Set the coordinates for the grid
    x_coords = vtk.vtkDoubleArray()
    y_coords = vtk.vtkDoubleArray()
    z_coords = vtk.vtkDoubleArray()

    for i in range(len(X)):
        x_coords.InsertNextValue(X[i])
    for j in range(len(Y)):
        y_coords.InsertNextValue(Y[j])
    z_coords.InsertNextValue(0)  # Since it's a 2D grid, Z is constant

    grid.SetXCoordinates(x_coords)
    grid.SetYCoordinates(y_coords)
    grid.SetZCoordinates(z_coords)

    # Add each data array to the grid
    for name, data in data_dict.items():
        data_array = vtk.vtkDoubleArray()
        data_array.SetNumberOfComponents(1)
        data_array.SetName(name)

        for value in data.flatten():
            data_array.InsertNextValue(value)

        grid.GetPointData().AddArray(data_array)

    # Write the grid to a VTK file
    writer = vtk.vtkRectilinearGridWriter()
    writer.SetFileName(filename)
    writer.SetInputData(grid)
    writer.Write()

    print(f"VTK file '{filename}' written successfully.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import vtk
#       2 def write_rectilinear_vtk(X, Y, data_dict, filename):
#       3     # Create the rectilinear grid
#       4     grid = vtk.vtkRectilinearGrid()
#
# ModuleNotFoundError: No module named 'vtk'

# %%
# to run: python3 plot_meanprofiles.py
import numpy as np
import glob
import pandas as pd
import matplotlib.pyplot as plt
import re

def numerical_sort(value):
    numbers = re.findall(r'\d+', value)
    return int(numbers[0]) if numbers else 0

# Get the list of all CSV files in the directory
file_list = glob.glob('profiles/meanprofile*.csv')
file_list.sort(key=numerical_sort)
nstep = len(file_list)

# Initialize an empty list to store the dataframes
T_mean = []
S_mean = []
T_gradient = []
S_gradient = []
T_flux = []
S_flux = []

y = []

# Loop through each file and read it into a dataframe
for file in file_list:
    print(file)
    df = pd.read_csv(file, skiprows=1)
    array = df.values
    y = array[:,0]
    
    T_mean.append(array[:,1])
    S_mean.append(array[:,2])
    T_gradient.append(array[:,3])
    S_gradient.append(array[:,4])
    T_flux.append(array[:,5])
    S_flux.append(array[:,6])
    
T_mean = np.array(T_mean)
S_mean = np.array(S_mean)
T_gradient = np.array(T_gradient)
S_gradient = np.array(S_gradient)
T_flux = np.array(T_flux)
S_flux = np.array(S_flux)

Dens_mean = (S_mean-T_mean)+(1-0.5)*y
T_turbDiff = T_flux / T_gradient               # turbulent diffusivity
S_turbDiff = S_flux / S_gradient               # turbulent diffusivity

t = np.linspace(0, nstep, nstep) 

data_dict = {"T_mean": T_mean,
             "S_mean": S_mean,
             "T_gradient": T_gradient,
             "S_gradient": S_gradient,
             "T_flux": T_flux,
             "S_flux": T_flux}


X, Y = np.meshgrid(t, y)

plt.figure(figsize=(10, 3))
plt.pcolormesh(X,Y,T_mean.T, cmap='viridis',shading='gouraud')
plt.colorbar()
plt.xlabel('Time')
plt.ylabel('y')
plt.title(r'$\langle\theta\rangle_h$')
plt.show()

plt.figure(figsize=(10, 3))
plt.pcolormesh(X,Y,S_mean.T, cmap='viridis',shading='gouraud')
plt.colorbar()
plt.xlabel('Time')
plt.ylabel('y')
plt.title(r'$\langle s\rangle_h$')
plt.show()

plt.figure(figsize=(10, 3))
plt.pcolormesh(X,Y,Dens_mean.T, cmap='viridis',shading='gouraud')
plt.colorbar()
plt.xlabel('Time')
plt.ylabel('y')
plt.title(r'$\langle\rho\rangle_h$')
plt.show()

plt.figure(figsize=(10, 3))
plt.pcolormesh(X,Y,T_gradient.T, cmap='viridis',shading='gouraud')
plt.colorbar()
plt.xlabel('Time')
plt.ylabel('y')
plt.title(r'$\langle\partial_y \theta\rangle_h$')
plt.show()

plt.figure(figsize=(10, 3))
plt.pcolormesh(X,Y,S_gradient.T, cmap='viridis',shading='gouraud')
plt.colorbar()
plt.xlabel('Time')
plt.ylabel('y')
plt.title(r'$\langle\partial_y s\rangle_h$')
plt.show()

plt.figure(figsize=(10, 3))
plt.pcolormesh(X,Y,T_flux.T, cmap='viridis',shading='gouraud')
plt.colorbar()
plt.xlabel('Time')
plt.ylabel('y')
plt.title(r'$\langle v \theta\rangle_h$')
plt.show()

plt.figure(figsize=(10, 3))
plt.pcolormesh(X,Y,S_flux.T, cmap='viridis',shading='gouraud')
plt.colorbar()
plt.xlabel('Time')
plt.ylabel('y')
plt.title(r'$\langle v s\rangle_h$')
plt.show()

plt.figure(figsize=(10, 3))
plt.pcolormesh(X,Y,T_turbDiff.T, cmap='viridis',shading='gouraud')
plt.colorbar()
plt.xlabel('Time')
plt.ylabel('y')
plt.title(r'$\langle v \theta\rangle_h / \langle\partial_y \theta\rangle_h$')
plt.show()

plt.figure(figsize=(10, 3))
plt.pcolormesh(X,Y,S_turbDiff.T, cmap='viridis',shading='gouraud')
plt.colorbar()
plt.xlabel('Time')
plt.ylabel('y')
plt.title(r'$\langle v s\rangle_h / \langle\partial_y s\rangle_h$')
plt.show()
# Out:
# profiles\meanprofile0.csv
# profiles\meanprofile1.csv
# profiles\meanprofile2.csv
# profiles\meanprofile3.csv
# profiles\meanprofile4.csv
# profiles\meanprofile5.csv
# profiles\meanprofile6.csv
# profiles\meanprofile7.csv
# profiles\meanprofile8.csv
# profiles\meanprofile9.csv
# profiles\meanprofile10.csv
# profiles\meanprofile11.csv
# profiles\meanprofile12.csv
# profiles\meanprofile13.csv
# profiles\meanprofile14.csv
# profiles\meanprofile15.csv
# profiles\meanprofile16.csv
# profiles\meanprofile17.csv
# profiles\meanprofile18.csv
# profiles\meanprofile19.csv
# profiles\meanprofile20.csv
# profiles\meanprofile21.csv
# profiles\meanprofile22.csv
# profiles\meanprofile23.csv
# profiles\meanprofile24.csv
# profiles\meanprofile25.csv
# profiles\meanprofile26.csv
# profiles\meanprofile27.csv
# profiles\meanprofile28.csv
# profiles\meanprofile29.csv
# profiles\meanprofile30.csv
# profiles\meanprofile31.csv
# profiles\meanprofile32.csv
# profiles\meanprofile33.csv
# profiles\meanprofile34.csv
# profiles\meanprofile35.csv
# profiles\meanprofile36.csv
# profiles\meanprofile37.csv
# profiles\meanprofile38.csv
# profiles\meanprofile39.csv
# profiles\meanprofile40.csv
# profiles\meanprofile41.csv
# profiles\meanprofile42.csv
# profiles\meanprofile43.csv
# profiles\meanprofile44.csv
# profiles\meanprofile45.csv
# profiles\meanprofile46.csv
# profiles\meanprofile47.csv
# profiles\meanprofile48.csv
# profiles\meanprofile49.csv
# profiles\meanprofile50.csv
# profiles\meanprofile51.csv
# profiles\meanprofile52.csv
# profiles\meanprofile53.csv
# profiles\meanprofile54.csv
# profiles\meanprofile55.csv
# profiles\meanprofile56.csv
# profiles\meanprofile57.csv
# profiles\meanprofile58.csv
# profiles\meanprofile59.csv
# profiles\meanprofile60.csv
# profiles\meanprofile61.csv
# profiles\meanprofile62.csv
# profiles\meanprofile63.csv
# profiles\meanprofile64.csv
# profiles\meanprofile65.csv
# profiles\meanprofile66.csv
# profiles\meanprofile67.csv
# profiles\meanprofile68.csv
# profiles\meanprofile69.csv
# profiles\meanprofile70.csv
# profiles\meanprofile71.csv
# profiles\meanprofile72.csv
# profiles\meanprofile73.csv
# profiles\meanprofile74.csv
# profiles\meanprofile75.csv
# profiles\meanprofile76.csv
# profiles\meanprofile77.csv
# profiles\meanprofile78.csv
# profiles\meanprofile79.csv
# profiles\meanprofile80.csv
# profiles\meanprofile81.csv
# profiles\meanprofile82.csv
# profiles\meanprofile83.csv
# profiles\meanprofile84.csv
# profiles\meanprofile85.csv
# profiles\meanprofile86.csv
# profiles\meanprofile87.csv
# profiles\meanprofile88.csv
# profiles\meanprofile89.csv
# profiles\meanprofile90.csv
# profiles\meanprofile91.csv
# profiles\meanprofile92.csv
# profiles\meanprofile93.csv
# profiles\meanprofile94.csv
# profiles\meanprofile95.csv
# profiles\meanprofile96.csv
# profiles\meanprofile97.csv
# profiles\meanprofile98.csv
# profiles\meanprofile99.csv
# profiles\meanprofile100.csv
# profiles\meanprofile101.csv
# profiles\meanprofile102.csv
# profiles\meanprofile103.csv
# profiles\meanprofile104.csv
# profiles\meanprofile105.csv
# profiles\meanprofile106.csv
# profiles\meanprofile107.csv
# profiles\meanprofile108.csv
# profiles\meanprofile109.csv
# profiles\meanprofile110.csv
# profiles\meanprofile111.csv
# profiles\meanprofile112.csv
# profiles\meanprofile113.csv
# profiles\meanprofile114.csv
# profiles\meanprofile115.csv
# profiles\meanprofile116.csv
# profiles\meanprofile117.csv
# profiles\meanprofile118.csv
# profiles\meanprofile119.csv
# profiles\meanprofile120.csv
# profiles\meanprofile121.csv
# profiles\meanprofile122.csv
# profiles\meanprofile123.csv
# profiles\meanprofile124.csv
# profiles\meanprofile125.csv
# profiles\meanprofile126.csv
# profiles\meanprofile127.csv
# profiles\meanprofile128.csv
# profiles\meanprofile129.csv
# profiles\meanprofile130.csv
# profiles\meanprofile131.csv
# profiles\meanprofile132.csv
# profiles\meanprofile133.csv
# profiles\meanprofile134.csv
# profiles\meanprofile135.csv
# profiles\meanprofile136.csv
# profiles\meanprofile137.csv
# profiles\meanprofile138.csv
# profiles\meanprofile139.csv
# profiles\meanprofile140.csv
# profiles\meanprofile141.csv
# profiles\meanprofile142.csv
# profiles\meanprofile143.csv
# profiles\meanprofile144.csv
# profiles\meanprofile145.csv
# profiles\meanprofile146.csv
# profiles\meanprofile147.csv
# profiles\meanprofile148.csv
# profiles\meanprofile149.csv
# profiles\meanprofile150.csv
# profiles\meanprofile151.csv
# profiles\meanprofile152.csv
# profiles\meanprofile153.csv
# profiles\meanprofile154.csv
# profiles\meanprofile155.csv
# profiles\meanprofile156.csv
# profiles\meanprofile157.csv
# profiles\meanprofile158.csv
# profiles\meanprofile159.csv
# profiles\meanprofile160.csv
# profiles\meanprofile161.csv
# profiles\meanprofile162.csv
# profiles\meanprofile163.csv
# profiles\meanprofile164.csv
# profiles\meanprofile165.csv
# profiles\meanprofile166.csv
# profiles\meanprofile167.csv
# profiles\meanprofile168.csv
# profiles\meanprofile169.csv
# profiles\meanprofile170.csv
# profiles\meanprofile171.csv
# profiles\meanprofile172.csv
# profiles\meanprofile173.csv
# profiles\meanprofile174.csv
# profiles\meanprofile175.csv
# profiles\meanprofile176.csv
# profiles\meanprofile177.csv
# profiles\meanprofile178.csv
# profiles\meanprofile179.csv
# profiles\meanprofile180.csv

# %%
import sympy as sp
import numpy as np

# Define the variables
y, R = sp.symbols('y R')

# Define the function
f = -1/2 * (sp.tanh(R*(y - 1/3)) + sp.tanh(R*(y + 1/3)))
# f = sp.tanh(R*(y - 1/3))
# f = sp.tanh(R*(y + 1/3))
# f = (sp.tanh(R*(y - 1/3)) + sp.tanh(R*(y + 1/3)))
# Expand the function using Taylor series
f_approx = sp.expand(f.series(y, 0, 4))

print(f_approx)
# Out:
# -1.0*R*y + 1.0*R*y*tanh(0.333333333333333*R)**2 + 0.333333333333333*R**3*y**3 - 1.33333333333333*R**3*y**3*tanh(0.333333333333333*R)**2 + 1.0*R**3*y**3*tanh(0.333333333333333*R)**4 + O(y**4)
